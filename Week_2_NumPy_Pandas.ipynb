# %% [markdown]
# **Week 2: NumPy and Pandas**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# **Practice Questions for numpy**

# %% [markdown]
# 1. Define two custom numpy arrays, say A and B. Generate two new numpy arrays by stacking A and B vertically and horizontally.

# %%
a = np.array([i for i in range(0,7)])
b = np.array([i for i in range(7,0,-1)])

# %%
np.vstack((a,b))
# Out:
# array([[0, 1, 2, 3, 4, 5, 6],
#        [7, 6, 5, 4, 3, 2, 1]])

# %%
np.hstack((a,b))
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1])

# %% [markdown]
# 2. Find common elements between A and B.

# %%
intersection = set(a).intersection(set(b))
np.array(intersection)
# Out:
# array({1, 2, 3, 4, 5, 6}, dtype=object)

# %% [markdown]
# 3. Extract all numbers from A which are within a specific range. eg between 5 and 10. [Hint: np.where() might be useful or boolean masks]

# %%
condition = (a>5) & (a<10) 
a[condition]
# Out:
# array([6])

# %% [markdown]
# 4. Filter the rows of iris_2d that has petallength (3rd column) > 1.5 and sepallength (1st column) < 5.0

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris_2d = np.genfromtxt(url, delimiter=',', dtype='float', usecols=[0,1,2,3])

# %%
condition = (iris_2d[:,3]>1.5) & (iris_2d[:,1]<5)
iris_2d[condition]
# Out:
# array([[6.3, 3.3, 4.7, 1.6],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.7, 5.1, 1.6],
#        [6. , 3.4, 4.5, 1.6],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
# ...

# %% [markdown]
# Practice Questions for Pandas

# %% [markdown]
# 1. From df filter the 'Manufacturer', 'Model' and 'Type' for every 20th row starting from 1st (row 0).
#
# df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %%
df[['Manufacturer', 'Model','Type']].iloc[::20]
# Out:
#    Manufacturer    Model     Type
# 0         Acura  Integra    Small
# 20     Chrysler  LeBaron  Compact
# 40        Honda  Prelude   Sporty
# 60      Mercury   Cougar  Midsize
# 80       Subaru   Loyale    Small

# %% [markdown]
# 2. Replace missing values in Min.Price and Max.Price columns with their respective mean.
#
# df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %%
condition = df[["Min.Price","Max.Price"]]
mean = condition.mean()

# %%
df[["Min.Price","Max.Price"]] = df[["Min.Price","Max.Price"]].fillna(mean)

# %%
print("After applying the filter the number of NaN values are as follows: ")
df[["Min.Price","Max.Price"]].isna().count()
# Out:
# After applying the filter the number of NaN values are as follows:
# Min.Price    93
# Max.Price    93
# dtype: int64

# %% [markdown]
# 3. How to get the rows of a dataframe with row sum > 100?
#
# df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))

# %%
df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))
df[df.sum(axis=1)>10]
# Out:
#      0   1   2   3
# 0   26  25  19  38
# 1   13  34  36  36
# 2   37  22  24  29
# 3   13  27  29  32
# 4   11  29  16  14
# 5   12  30  18  29
# 6   22  19  28  28
# 7   13  20  13  27
# 8   24  17  21  24
# 9   19  10  26  21
# 10  22  33  33  37
# 11  27  12  16  29
# 12  18  26  31  39
# 13  21  31  25  15
# 14  29  15  38  36
